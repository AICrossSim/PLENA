# %%
from cfl_tools import PROJECT_PATH
target_folder = PROJECT_PATH / "test" / "Instr_Level_Benchmark" / "build" / "vect_fp_exp"
mem_file = open(PROJECT_PATH / "test" / "Instr_Level_Benchmark" / "vect_fp.mem", "r")

for line in mem_file:
    print(line)

mem_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from cfl_tools import PROJECT_PATH
# ----> 2 mem_file = open(PROJECT_PATH / "test" / "Instr_Level_Benchmark" / "vect_fp.mem", "r")
#       4 for line in mem_file:
#       5     print(line)
#
# File /workspace/.coprocessor_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/test/Instr_Level_Benchmark/vect_fp.mem'

# %%
from cfl_cocotb.torch_fp_conversion import fp_2_bin
import torch
bin_fp = fp_2_bin(torch.tensor(1), 7, 8)
# Out:
# /workspace/tools/cfl_cocotb/torch_fp_conversion.py:98: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   fp = torch.tensor(fp)

# %%
bin_fp
# Out:
# (tensor([1.]), tensor(16128, dtype=torch.int32))
